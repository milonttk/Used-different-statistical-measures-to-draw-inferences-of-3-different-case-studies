# %%
import numpy as np
import pandas as pd
from numpy.random import randn
from scipy.stats import f
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
import seaborn as sborn
import scipy.stats as stats

# %%
#mydata = pd.read_excel('Wholesale customers data-1.xlsx')
#mydata

# %%
mydata1 = pd.read_excel('Wholesale customers data-1.xlsx',sheet_name='Wholesale customers data')
mydata1
# Out:
#      Buyer/Spender Channel Region  Fresh   Milk  Grocery  Frozen  \
# 0                1  Retail  Other  12669   9656     7561     214
# 1                2  Retail  Other   7057   9810     9568    1762
# 2                3  Retail  Other   6353   8808     7684    2405
# 3                4   Hotel  Other  13265   1196     4221    6404
# 4                5  Retail  Other  22615   5410     7198    3915
# ..             ...     ...    ...    ...    ...      ...     ...
# 435            436   Hotel  Other  29703  12051    16027   13135
# 436            437   Hotel  Other  39228   1431      764    4510
# 437            438  Retail  Other  14531  15488    30243     437
# 438            439   Hotel  Other  10290   1981     2232    1038
# 439            440   Hotel  Other   2787   1698     2510      65
#
#      Detergents_Paper  Delicatessen
# 0                2674          1338
# 1                3293          1776
# 2                3516          7844
# 3                 507          1788
# ...

# %%
#new_data1=mydata.drop(mydata.index[0])
#new_data1

# %%
#mydata.describe(include="all")

# %%
mydata1.describe()
# Out:
#        Buyer/Spender          Fresh          Milk       Grocery        Frozen  \
# count     440.000000     440.000000    440.000000    440.000000    440.000000
# mean      220.500000   12000.297727   5796.265909   7951.277273   3071.931818
# std       127.161315   12647.328865   7380.377175   9503.162829   4854.673333
# min         1.000000       3.000000     55.000000      3.000000     25.000000
# 25%       110.750000    3127.750000   1533.000000   2153.000000    742.250000
# 50%       220.500000    8504.000000   3627.000000   4755.500000   1526.000000
# 75%       330.250000   16933.750000   7190.250000  10655.750000   3554.250000
# max       440.000000  112151.000000  73498.000000  92780.000000  60869.000000
#
#        Detergents_Paper  Delicatessen
# count        440.000000    440.000000
# mean        2881.493182   1524.870455
# std         4767.854448   2820.105937
# min            3.000000      3.000000
# 25%          256.750000    408.250000
# ...

# %%
mydata1
# Out:
#      Buyer/Spender Channel Region  Fresh   Milk  Grocery  Frozen  \
# 0                1  Retail  Other  12669   9656     7561     214
# 1                2  Retail  Other   7057   9810     9568    1762
# 2                3  Retail  Other   6353   8808     7684    2405
# 3                4   Hotel  Other  13265   1196     4221    6404
# 4                5  Retail  Other  22615   5410     7198    3915
# ..             ...     ...    ...    ...    ...      ...     ...
# 435            436   Hotel  Other  29703  12051    16027   13135
# 436            437   Hotel  Other  39228   1431      764    4510
# 437            438  Retail  Other  14531  15488    30243     437
# 438            439   Hotel  Other  10290   1981     2232    1038
# 439            440   Hotel  Other   2787   1698     2510      65
#
#      Detergents_Paper  Delicatessen
# 0                2674          1338
# 1                3293          1776
# 2                3516          7844
# 3                 507          1788
# ...

# %%
df = mydata1

# %%
df = mydata1
k=pd.pivot_table(df,values=['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicatessen'], index=['Region','Channel'],aggfunc=np.sum)
k
# Out:
#                 Delicatessen  Detergents_Paper    Fresh  Frozen  Grocery  \
# Region Channel
# Lisbon Hotel           70632             56081   761233  184512   237542
#        Retail          33695            148055    93600   46514   332495
# Oporto Hotel           30965             13516   326215  160861   123074
#        Retail          23541            159795   138506   29271   310200
# Other  Hotel          320358            165990  2928269  771606   820101
#        Retail         191752            724420  1032308  158886  1675150
#
#                    Milk
# Region Channel
# Lisbon Hotel     228342
#        Retail    194112
# Oporto Hotel      64519
#        Retail    174625
# Other  Hotel     735753
#        Retail   1153006

# %%
tab_tots = k.groupby(level='Region').mean()
l=tab_tots.sum(axis = 1)
l
l.plot()

# %%
tab_tots2 = k.groupby(level='Channel').mean()
l2=tab_tots2.sum(axis = 1)
l2
l2.plot()

# %%
l3=k.query('Channel == ["Hotel"]')
l5=k.query('Channel == ["Retail"]')
l4=l3.sum(axis = 1)
l6=l5.sum(axis = 1)
l4.plot()

# %%
l6.plot()

# %%
k.plot(figsize=(20,10),fontsize=10)

# %%
k['Fresh'].plot(figsize=(10,5),fontsize=10)

# %%
k['Milk'].plot(figsize=(10,5),fontsize=10)

# %%
 k['Grocery'].plot(figsize=(10,5),fontsize=10)

# %%
k['Frozen'].plot(figsize=(10,5),fontsize=10)

# %%
k['Detergents_Paper'].plot(figsize=(10,5),fontsize=10)

# %%
 k['Delicatessen'].plot(figsize=(10,5),fontsize=10)

# %%
#n=k.mean()
#n
r=k.var()#higher value of variance means higher variability
r.plot(figsize=(10,5),fontsize=10)

# %%
p=k.std()
p
p.plot(figsize=(10,5),fontsize=10)

# %%
u=k.max()
e=k.min()
d=u-e#range calculation, higher range means higher variability
d.plot(figsize=(10,5),fontsize=10)

# %%
Q1 = mydata1.quantile(0.25)
Q3 = mydata1.quantile(0.75)
IQR = Q3 - Q1
IQR
lb = Q1 -(1.5 * IQR) 
ub = Q3 +(1.5 * IQR) 
gh=((mydata1< (Q1 - 1.5 * IQR)) | (mydata1> (Q3 + 1.5 * IQR)))
gh
gh[gh == 1].count()# items are having outliers
# Out:
# Buyer/Spender        0
# Channel              0
# Delicatessen        27
# Detergents_Paper    30
# Fresh               20
# Frozen              43
# Grocery             24
# Milk                28
# Region               0
# dtype: int64

# %%
dn=mydata1
sborn.set(font_scale=1)
plt.figure(figsize=(20,10))
_, fig = pd.DataFrame.boxplot(dn, return_type='both')
